# %% [markdown]
# ## 파이썬 BeautifulSoup를 활용한 웹 크롤링
#
# - https://comp.fnguide.com/SVO2/ASP/SVD_Finance.asp?pGB=1&gicode=A005930&cID=&MenuYn=Y&ReportGB=&NewMenuID=103&stkGb=701
#     위의 사이트를 크롤링
#
#  - 손익계산서 크롤링

# %%
import pandas as pd
import numpy as np
from datetime import datetime
from bs4 import BeautifulSoup
from urllib.request import urlopen, Request
import sqlalchemy

# %%
stock = ['005930', 'KOSPI', '삼성전자']
rpt_type = 'CONSOLIDATED'
freq = 'Q'

# %%
headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
                      "AppleWebKit/537.36 (KHTML, like Gecko) Chrome/100.0.4896.151 "
                      "Whale/3.14.134.62 Safari/537.36"
    }
if rpt_type.upper() == 'CONSOLIDATED':  # 연결 연간/분기 손익 계산서
    url = "https://comp.fnguide.com/SVO2/ASP/SVD_Finance.asp?pGB=1&gicode=A{}&cID=&MenuYn=Y&ReportGB=D&NewMenuID=103&stkGb=701".format(
        stock[0])
else:  # 별도 연간/분기 손익계산서
    url = "https://comp.fnguide.com/SVO2/ASP/SVD_Finance.asp?pGB=1&gicode=A{}&cID=&MenuYn=Y&ReportGB=B&NewMenuID=103&stkGb=701".format(
        stock[0])

# %%
req = Request(url=url, headers=headers)
html = urlopen(req).read()
soup = BeautifulSoup(html, 'html.parser')

# %%
html
# Out:
# b'\r\n<!DOCTYPE html>\r\n<html lang="ko">\r\n<head>\r\n    \r\n<link rel="stylesheet" href="https://cdn.fnguide.com/SVO2/css/compeach.css?ver2109131021">\r\n<!--[if lte IE 9]><link rel="stylesheet" href="https://cdn.fnguide.com/SVO2/css/ie9.css?ver3"><![endif]-->\r\n<meta http-equiv="X-UA-Compatible" content="IE=edge">\r\n<meta charset="utf-8">\r\n<meta content="width=device-width" name="viewport">\r\n<!-- <meta content="width=device-width,initial-scale=1.0,minimum-scale=1.0,maximum-scale=1.0" name="viewport"> -->\r\n<script type="text/javascript" src="https://cdn.fnguide.com/SVO2/js/lib/jquery-1.11.1.min.js?v=1.0.6"></script>\r\n<script type="text/javascript" src="https://cdn.fnguide.com/SVO2/js/comp_load.js?v=1.0.6"></script>\r\n<script type="text/javascript" src="https://cdn.fnguide.com/SVO2/js/lib/jquery.autocomplete.js?v=1.0.6"></script>\r\n<link rel="stylesheet" type="text/css" href="https://cdn.fnguide.com/SVO2/css/jquery.autocomplete.css?v=1.0.1" />\r\n<LINK REL="SHORTCUT ICON" HREF="https://cdn.fnguide.com/SVO2/img/CompanyGuide.ico">\r\n<script type="text/javascript" src="https://cdn.fnguide.com/SVO2/js/autocomplete.js?v=1.0.6"></script>\r\n\r\n    <meta name="author" content="">\r\n    <meta name="description" content="">\r\n\t<title>\xec\x82\xbc\xec\x84\xb1\xec\xa0\x84\xec\x9e\x90(A005930) | \xec\x9e\xac\xeb\xac\xb4\xec\xa0\x9c\xed\x91\x9c | \xea\xb8\xb0\xec\x97\x85\xec\xa0\x95\xeb\xb3\xb4 | Company Guide</title>\r\n    <script>\r\n      ///SVO2/xml/Finance_C_IFRS/005930.xml\r\n        $(function(){\r\n            if ($(\'#stkGb\').val() !=\'751\' && $(\'#gv_stkGb\').val() !=\'754\'){\r\n                //$(\'#divData\').show();\r\n                //\xed\x83\xad\xed\x81\xb4\xeb\xa6\xad\xec\x9d\xb4\xeb\xb2\xa4\xed\x8a\xb8 \r\n\t\t\t\tif ($(\'#ReportGB\').val()=="B" || $(\'#ReportGB\').val()=="A" ) {\r\n                    $(\'div#divReportGb > a\').eq(1).addClass(\'ac\');  \r\n                    $(\'div#divReportGb > a\').eq(0).removeClass(\'ac\');\r\n\t\t\t\t\t$(\'#ReportGB\').val("B");\r\n                }else{\r\n                    $(\'div#divReportGb > a\').eq(1).removeClass(\'ac\');   \r\n                    $(\'div#divReportGb > a\').eq(0).addClass(\'ac\'); \r\n\t\t\t\t\t$(\'#ReportGB\').val("D");\r\n                }\r\n\t\t\t\t\r\n\t\t\t\t$(\'#sonkiYQ\').val($.cookie(\'finance_cook_sonkiYQ\'));\r\n\t\t\t\t$(\'#daechaYQ\').val($.cookie(\'finance_cook_daechaYQ\'));\r\n\t\t\t\t$(\'#cashYQ\').val($.cookie(\'finance_cook_cashYQ\'));\r\n\t\t\t\t\r\n\t\t\t\tif ($(\'#sonkiYQ\').val() =="Q"){\t\r\n\t\t\t\t\t$(\'#btnSonik_Q\').addClass("ac");\r\n\t\t\t\t\t$(\'#btnSonikYQText\').html("[\xeb\xb6\x84\xea\xb8\xb0]");\r\n\t\t\t\t\t$("#sonikChart1").attr(\'src\',\'https://cdn.fnguide.com/SVO2/chartImg/03_01/A005930_\'+$(\'#ReportGB\').val()+\'_Q_03_01.png\');\r\n\t\t\t\t\t$("#sonikChart2").attr(\'src\',\'https://cdn.fnguide.com/SVO2/chartImg/03_02/A005930_\'+$(\'#ReportGB\').val()+\'_Q_03_02.png\');\r\n\t\t\t\t\t$("#divSonikQ").show();\r\n\r\n\t\t\t\t}else{\r\n\t\t\t\t\t$(\'#btnSonik_Y\').addClass("ac");\r\n\t\t\t\t\t$(\'#btnSonikYQText\').html("[\xec\x97\xb0\xea\xb0\x84]");\r\n\t\t\t\t\t$("#sonikChart1").attr(\'src\',\'https://cdn.fnguide.com/SVO2/chartImg/03_01/A005930_\'+$(\'#ReportGB\').val()+\'_D_03_01.png\');\r\n\t\t\t\t\t$("#sonikChart2").attr(\'src\',\'https://cdn.fnguide.com/SVO2/chartImg/03_02/A005930_\'+$(\'#ReportGB\').val()+\'_D_03_02.png\');\r\n\t\t\t\t\t$("#divSonikY").show();\r\n\t\t\t\t}\r\n\r\n\t\t\t\tif ($(\'#daechaYQ\').val() =="Q"){\t\r\n\t\t\t\t\t$(\'#btnDaecha_Q\').addClass("ac")\r\n\t\t\t\t\t$(\'#btnDaechaYQText\').html("[\xeb\xb6\x84\xea\xb8\xb0]");\r\n\t\t\t\t\t$("#deachaChart1").attr(\'src\',\'https://cdn.fnguide.com/SVO2/chartImg/03_03/A005930_\'+$(\'#ReportGB\').val()+\'_Q_03_03.png\');\r\n\t\t\t\t\t$("#deachaChart2").attr(\'src\',\'https://cdn.fnguide.com/SVO2/chartImg/03_04/A005930_\'+$(\'#ReportGB\').val()+\'_Q_03_04.png\');\r\n\t\t\t\t\t$("#divDaechaQ").show();\r\n\t\t\t\t}else{\r\n\t\t\t\t ...

# %%
if freq.upper() == 'A':  # 연간 손익계산서 영역
    is_a = soup.find(id='divSonikY')
    num_col = 4  # 최근 4개 데이터
else:  # 분기 손익계산서 영역
    is_a = soup.find(id='divSonikQ')
    num_col = 4  # 최근 4개 데이터
is_a = is_a.find_all(['tr'])
is_a
# Out:
# [<tr>
#  <th class="clf tbold" scope="col">IFRS(연결)</th>
#  <th scope="col">2021/06</th>
#  <th scope="col">2021/09</th>
#  <th scope="col">2021/12</th>
#  <th scope="col">2022/03</th>
#  <th scope="col">전년동기</th>
#  <th class="cle" scope="col">전년동기(%)</th>
#  </tr>,
#  <tr class="rwf rowBold">
#  <th class="l clf" scope="row">
#  <div class="th_b">매출액</div>
#  </th>
#  <td class="r" title="636,715.85">636,716</td>
#  <td class="r" title="739,791.87">739,792</td>
#  <td class="r" title="765,655.24">765,655</td>
#  <td class="r" title="777,814.98">777,815</td>
#  <td class="r" title="653,885.03">653,885</td>
#  <td class="r cle">19.0</td>
#  </tr>,
#  <tr class="rwf">
#  <th class="l clf" scope="row">
#  <div class="">매출원가</div>
#  </th>
#  <td class="r" title="370,659.31">370,659</td>
#  <td class="r" title="428,988.71">428,989</td>
#  <td class="r" title="449,465.55">449,466</td>
#  <td class="r" title="470,720.57">470,721</td>
#  <td class="r" title="414,999.85">415,000</td>
#  <td class="r cle">13.4</td>
#  </tr>,
#  <tr class="rwf">
#  <th class="l clf" scope="row">
#  <div class="">매출총이익</div>
#  </th>
#  <td class="r" title="266,056.54">266,057</td>
#  <td class="r" title="310,803.16">310,803</td>
#  <td class="r" title="316,189.69">316,190</td>
#  <td class="r" title="307,094.41">307,094</td>
#  <td class="r" title="238,885.18">238,885</td>
#  <td class="r cle">28.6</td>
#  </tr>,
#  <tr class="rwf acd_dep_start_close" id="p_grid1Q_4">
#  <th class="l clf" scope="row">
#  <div class=""><span class="txt_acd">판매비와관리비</span><a class="btn_acdopen" href="javascript:foldOpen('grid1Q_4');" id="grid1Q_4"><span class="blind" id="span_grid1Q_4">계산에 참여한 계정 펼치기</span></a></div>
#  </th>
#  <td class="r" title="140,389.09">140,389</td>
#  <td class="r" title="152,627.85">152,628</td>
#  <td class="r" title="177,522.57">177,523</td>
#  <td class="r" title="165,880.32">165,880</td>
#  <td class="r" title="145,056.50">145,057</td>
#  <td class="r cle">14.4</td>
#  </tr>,
#  <tr class="c_grid1Q_4 rwf acd_dep2_sub" style="display:none;">
#  <th class="l clf" scope="row">   인건비</th>
#  <td class="r" title="17,255.88">17,256</td>
#  <td class="r" title="18,634.32">18,634</td>
#  <td class="r" title="20,934.16">20,934</td>
#  <td class="r" title="20,726.47">20,726</td>
#  <td class="r" title="18,743.68">18,744</td>
#  <td class="r cle">10.6</td>
#  </tr>,
#  <tr class="c_grid1Q_4 rwf acd_dep2_sub" style="display:none;">
#  <th class="l clf" scope="row">   유무형자산상각비</th>
#  <td class="r" title="5,134.25">5,134</td>
#  <td class="r" title="5,193.75">5,194</td>
#  <td class="r" title="5,225.94">5,226</td>
#  <td class="r" title="5,472.35">5,472</td>
#  <td class="r" title="5,176.57">5,177</td>
#  <td class="r cle">5.7</td>
#  </tr>,
#  <tr class="c_grid1Q_4 rwf acd_dep2_sub" style="display:none;">
#  <th class="l clf" scope="row">   연구개발비</th>
#  <td class="r" title="53,825.16">53,825</td>
#  <td class="r" title="51,098.90">51,099</td>
#  <td class="r" title="64,687.76">64,688</td>
#  <td class="r" title="59,222.32">59,222</td>
#  <td class="r" title="54,405.44">54,405</td>
#  <td class="r cle">8.9</td>
#  </tr>,
#  <tr class="c_grid1Q_4 rwf acd_dep2_sub" style="display:none;">
#  <th class="l clf" scope="row">   광고선전비</th>
#  <td class="r" title="11,189.91">11,190</td>
#  <td class="r" title="15,376.92">15,377</td>
#  <td class="r" title="16,089.63">16,090</td>
#  <td class="r" title="14,677.01">14,677</td>
#  <td class="r" title="11,103.69">11,104</td>
#  <td class="r cle">32.2</td>
#  </tr>,
#  <tr class="c_grid1Q_4 rwf acd_dep2_sub" style="display:none;">
#  <th class="l clf" scope="row">   판매비</th>
#  <td class="r" title="26,458.35">26,458</td>
#  <td class="r" title="35,628.16">35,628</td>
#  <td class="r" title="38,558.94">38,559</td>
#  <td class="r" title="35,745.75">35,746</td>
#  <td class="r" title="30,539.46">30,539</td>
#  <td class="r cle">17.0</td>
#  </tr>,
#  <tr class="c_grid1Q_4 rwf acd_dep2_sub" style="display:none;">
#  <th class="l clf" scope="row">   관리비</th>
#  <td class="r" title="14,686.37">14,686</td>
#  <td class="r" title="14,454.61">14,455</td>
#  <td class="r" title="18,174.77">18,175</td>
#  <td class="r" title="17,303.91">17,304</td>
#  <td class="r" title="14,609.93">14,610</td>
#  <td class="r cle">18.4</td>
#  </tr>,
#  <tr class="c_grid1Q_4 rwf acd_dep2_sub" style="display:none;">
#  <th class="l clf" scope="row">   기타원가성비용</th>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r cle"> </td>
#  </tr>,
#  <tr class="c_grid1Q_4 rwf acd_dep2_sub" style="display:none;">
#  <th class="l clf" scope="row">   기타</th>
#  <td class="r" title="11,839.17">11,839</td>
#  <td class="r" title="12,241.19">12,241</td>
#  <td class="r" title="13,851.37">13,851</td>
#  <td class="r" title="12,732.51">12,733</td>
#  <td class="r" title="10,477.73">10,478</td>
#  <td class="r cle">21.5</td>
#  </tr>,
#  <tr class="rwf rowBold">
#  <th class="l clf" scope="row">
#  <div class="th_b">영업이익</div>
#  </th>
#  <td class="r" title="125,667.45">125,667</td>
#  <td class="r" title="158,175.31">158,175</td>
#  <td class="r" title="138,667.12">138,667</td>
#  <td class="r" title="141,214.09">141,214</td>
#  <td class="r" title="93,828.68">93,829</td>
#  <td class="r cle">50.5</td>
#  </tr>,
#  <tr class="rwf rowBold">
#  <th class="l clf" scope="row">
#  <div class="th_b">영업이익(발표기준)</div>
#  </th>
#  <td class="r" title="125,667.45">125,667</td>
#  <td class="r" title="158,175.31">158,175</td>
#  <td class="r" title="138,667.12">138,667</td>
#  <td class="r" title="141,214.09">141,214</td>
#  <td class="r" title="93,828.68">93,829</td>
#  <td class="r cle">50.5</td>
#  </tr>,
#  <tr class="rwf acd_dep_start_close" id="p_grid1Q_7">
#  <th class="l clf" scope="row">
#  <div class=""><span class="txt_acd">금융수익</span><a class="btn_acdopen" href="javascript:foldOpen('grid1Q_7');" id="grid1Q_7"><span class="blind" id="span_grid1Q_7">계산에 참여한 계정 펼치기</span></a></div>
#  </th>
#  <td class="r" title="17,871.43">17,871</td>
#  <td class="r" title="26,608.80">26,609</td>
#  <td class="r" title="18,565.26">18,565</td>
#  <td class="r" title="35,021.89">35,022</td>
#  <td class="r" title="22,386.38">22,386</td>
#  <td class="r cle">56.4</td>
#  </tr>,
#  <tr class="c_grid1Q_7 rwf acd_dep2_sub" style="display:none;">
#  <th class="l clf" scope="row">   이자수익</th>
#  <td class="r" title="2,541.33">2,541</td>
#  <td class="r" title="3,373.15">3,373</td>
#  <td class="r" title="3,542.82">3,543</td>
#  <td class="r" title="3,690.32">3,690</td>
#  <td class="r" title="3,325.48">3,325</td>
#  <td class="r cle">11.0</td>
#  </tr>,
#  <tr class="c_grid1Q_7 rwf acd_dep2_sub" style="display:none;">
#  <th class="l clf" scope="row">   배당금수익</th>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r cle"> </td>
#  </tr>,
#  <tr class="c_grid1Q_7 rwf acd_dep2_sub" style="display:none;">
#  <th class="l clf" scope="row">   외환이익</th>
#  <td class="r" title="14,090.02">14,090</td>
#  <td class="r" title="21,406.70">21,407</td>
#  <td class="r" title="12,679.67">12,680</td>
#  <td class="r" title="26,086.03">26,086</td>
#  <td class="r" title="17,080.37">17,080</td>
#  <td class="r cle">52.7</td>
#  </tr>,
#  <tr class="c_grid1Q_7 rwf acd_dep2_sub" style="display:none;">
#  <th class="l clf" scope="row">   대손충당금환입액</th>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r cle"> </td>
#  </tr>,
#  <tr class="c_grid1Q_7 rwf acd_dep2_sub" style="display:none;">
#  <th class="l clf" scope="row">   매출채권처분이익</th>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r cle"> </td>
#  </tr>,
#  <tr class="c_grid1Q_7 rwf acd_dep2_sub" style="display:none;">
#  <th class="l clf" scope="row">   당기손익-공정가치측정 금융자산관련이익</th>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r cle"> </td>
#  </tr>,
#  <tr class="c_grid1Q_7 rwf acd_dep2_sub" style="display:none;">
#  <th class="l clf" scope="row">   금융자산처분이익</th>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r cle"> </td>
#  </tr>,
#  <tr class="c_grid1Q_7 rwf acd_dep2_sub" style="display:none;">
#  <th class="l clf" scope="row">   금융자산평가이익</th>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r cle"> </td>
#  </tr>,
#  <tr class="c_grid1Q_7 rwf acd_dep2_sub" style="display:none;">
#  <th class="l clf" scope="row">   금융자산손상차손환입</th>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r cle"> </td>
#  </tr>,
#  <tr class="c_grid1Q_7 rwf acd_dep2_sub" style="display:none;">
#  <th class="l clf" scope="row">   파생상품이익</th>
#  <td class="r" title="1,240.08">1,240</td>
#  <td class="r" title="1,828.95">1,829</td>
#  <td class="r" title="2,342.77">2,343</td>
#  <td class="r" title="5,245.54">5,246</td>
#  <td class="r" title="1,980.53">1,981</td>
#  <td class="r cle">164.9</td>
#  </tr>,
#  <tr class="c_grid1Q_7 rwf acd_dep2_sub" style="display:none;">
#  <th class="l clf" scope="row">   기타금융수익</th>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r cle"> </td>
#  </tr>,
#  <tr class="rwf acd_dep_start_close" id="p_grid1Q_8">
#  <th class="l clf" scope="row">
#  <div class=""><span class="txt_acd">금융원가</span><a class="btn_acdopen" href="javascript:foldOpen('grid1Q_8');" id="grid1Q_8"><span class="blind" id="span_grid1Q_8">계산에 참여한 계정 펼치기</span></a></div>
#  </th>
#  <td class="r" title="15,227.17">15,227</td>
#  <td class="r" title="24,906.46">24,906</td>
#  <td class="r" title="16,973.09">16,973</td>
#  <td class="r" title="30,333.18">30,333</td>
#  <td class="r" title="19,938.82">19,939</td>
#  <td class="r cle">52.1</td>
#  </tr>,
#  <tr class="c_grid1Q_8 rwf acd_dep2_sub" style="display:none;">
#  <th class="l clf" scope="row">   이자비용</th>
#  <td class="r" title="742.32">742</td>
#  <td class="r" title="1,370.10">1,370</td>
#  <td class="r" title="1,238.56">1,239</td>
#  <td class="r" title="1,492.31">1,492</td>
#  <td class="r" title="964.42">964</td>
#  <td class="r cle">54.7</td>
#  </tr>,
#  <tr class="c_grid1Q_8 rwf acd_dep2_sub" style="display:none;">
#  <th class="l clf" scope="row">   외환손실</th>
#  <td class="r" title="11,862.26">11,862</td>
#  <td class="r" title="21,843.73">21,844</td>
#  <td class="r" title="13,806.42">13,806</td>
#  <td class="r" title="24,606.82">24,607</td>
#  <td class="r" title="17,348.52">17,349</td>
#  <td class="r cle">41.8</td>
#  </tr>,
#  <tr class="c_grid1Q_8 rwf acd_dep2_sub" style="display:none;">
#  <th class="l clf" scope="row">   대손상각비</th>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r cle"> </td>
#  </tr>,
#  <tr class="c_grid1Q_8 rwf acd_dep2_sub" style="display:none;">
#  <th class="l clf" scope="row">   당기손익-공정가치측정 금융자산관련손실</th>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r cle"> </td>
#  </tr>,
#  <tr class="c_grid1Q_8 rwf acd_dep2_sub" style="display:none;">
#  <th class="l clf" scope="row">   매출채권처분손실</th>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r cle"> </td>
#  </tr>,
#  <tr class="c_grid1Q_8 rwf acd_dep2_sub" style="display:none;">
#  <th class="l clf" scope="row">   금융자산처분손실</th>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r cle"> </td>
#  </tr>,
#  <tr class="c_grid1Q_8 rwf acd_dep2_sub" style="display:none;">
#  <th class="l clf" scope="row">   금융자산평가손실</th>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r cle"> </td>
#  </tr>,
#  <tr class="c_grid1Q_8 rwf acd_dep2_sub" style="display:none;">
#  <th class="l clf" scope="row">   금융자산손상차손</th>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r cle"> </td>
#  </tr>,
#  <tr class="c_grid1Q_8 rwf acd_dep2_sub" style="display:none;">
#  <th class="l clf" scope="row">   파생상품손실</th>
#  <td class="r" title="2,622.59">2,623</td>
#  <td class="r" title="1,692.63">1,693</td>
#  <td class="r" title="1,928.11">1,928</td>
#  <td class="r" title="4,234.05">4,234</td>
#  <td class="r" title="1,625.88">1,626</td>
#  <td class="r cle">160.4</td>
#  </tr>,
#  <tr class="c_grid1Q_8 rwf acd_dep2_sub" style="display:none;">
#  <th class="l clf" scope="row">   기타금융원가</th>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r cle"> </td>
#  </tr>,
#  <tr class="rwf acd_dep_start_close" id="p_grid1Q_9">
#  <th class="l clf" scope="row">
#  <div class=""><span class="txt_acd">기타수익</span><a class="btn_acdopen" href="javascript:foldOpen('grid1Q_9');" id="grid1Q_9"><span class="blind" id="span_grid1Q_9">계산에 참여한 계정 펼치기</span></a></div>
#  </th>
#  <td class="r" title="7,406.68">7,407</td>
#  <td class="r" title="4,251.52">4,252</td>
#  <td class="r" title="7,401.33">7,401</td>
#  <td class="r" title="7,001.93">7,002</td>
#  <td class="r" title="2,997.42">2,997</td>
#  <td class="r cle">133.6</td>
#  </tr>,
#  <tr class="c_grid1Q_9 rwf acd_dep2_sub" style="display:none;">
#  <th class="l clf" scope="row">   이자수익</th>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r cle"> </td>
#  </tr>,
#  <tr class="c_grid1Q_9 rwf acd_dep2_sub" style="display:none;">
#  <th class="l clf" scope="row">   배당금수익</th>
#  <td class="r" title="683.35">683</td>
#  <td class="r" title="216.69">217</td>
#  <td class="r" title="371.02">371</td>
#  <td class="r" title="2,685.09">2,685</td>
#  <td class="r" title="87.34">87</td>
#  <td class="r cle">2974.3</td>
#  </tr>,
#  <tr class="c_grid1Q_9 rwf acd_dep2_sub" style="display:none;">
#  <th class="l clf" scope="row">   외환이익</th>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r cle"> </td>
#  </tr>,
#  <tr class="c_grid1Q_9 rwf acd_dep2_sub" style="display:none;">
#  <th class="l clf" scope="row">   재고자산감모손실환입</th>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r cle"> </td>
#  </tr>,
#  <tr class="c_grid1Q_9 rwf acd_dep2_sub" style="display:none;">
#  <th class="l clf" scope="row">   재고자산폐기(처분)이익</th>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r cle"> </td>
#  </tr>,
#  <tr class="c_grid1Q_9 rwf acd_dep2_sub" style="display:none;">
#  <th class="l clf" scope="row">   당기손익-공정가치측정 금융자산평가이익</th>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r cle"> </td>
#  </tr>,
#  <tr class="c_grid1Q_9 rwf acd_dep2_sub" style="display:none;">
#  <th class="l clf" scope="row">   자산처분(폐기)이익</th>
#  <td class="r" title="1,305.50">1,306</td>
#  <td class="r" title="1,135.99">1,136</td>
#  <td class="r" title="207.80">208</td>
#  <td class="r" title="504.20">504</td>
#  <td class="r" title="754.71">755</td>
#  <td class="r cle"><span class="tcr">-33.2</span></td>
#  </tr>,
#  <tr class="c_grid1Q_9 rwf acd_dep2_sub" style="display:none;">
#  <th class="l clf" scope="row">   자산평가이익</th>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r cle"> </td>
#  </tr>,
#  <tr class="c_grid1Q_9 rwf acd_dep2_sub" style="display:none;">
#  <th class="l clf" scope="row">   자산손상차손환입</th>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r cle"> </td>
#  </tr>,
#  <tr class="c_grid1Q_9 rwf acd_dep2_sub" style="display:none;">
#  <th class="l clf" scope="row">   파생상품이익</th>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r cle"> </td>
#  </tr>,
#  <tr class="c_grid1Q_9 rwf acd_dep2_sub" style="display:none;">
#  <th class="l clf" scope="row">   임대료수익</th>
#  <td class="r" title="329.67">330</td>
#  <td class="r" title="326.17">326</td>
#  <td class="r" title="333.99">334</td>
#  <td class="r" title="345.84">346</td>
#  <td class="r" title="338.18">338</td>
#  <td class="r cle">2.3</td>
#  </tr>,
#  <tr class="c_grid1Q_9 rwf acd_dep2_sub" style="display:none;">
#  <th class="l clf" scope="row">   로열티수익</th>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r cle"> </td>
#  </tr>,
#  <tr class="c_grid1Q_9 rwf acd_dep2_sub" style="display:none;">
#  <th class="l clf" scope="row">   수수료수익</th>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r cle"> </td>
#  </tr>,
#  <tr class="c_grid1Q_9 rwf acd_dep2_sub" style="display:none;">
#  <th class="l clf" scope="row">   대손충당금환입</th>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r cle"> </td>
#  </tr>,
#  <tr class="c_grid1Q_9 rwf acd_dep2_sub" style="display:none;">
#  <th class="l clf" scope="row">   충당부채환입액</th>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r cle"> </td>
#  </tr>,
#  <tr class="c_grid1Q_9 rwf acd_dep2_sub" style="display:none;">
#  <th class="l clf" scope="row">   기타</th>
#  <td class="r" title="5,088.16">5,088</td>
#  <td class="r" title="2,572.67">2,573</td>
#  <td class="r" title="6,488.52">6,489</td>
#  <td class="r" title="3,466.80">3,467</td>
#  <td class="r" title="1,817.19">1,817</td>
#  <td class="r cle">90.8</td>
#  </tr>,
#  <tr class="rwf acd_dep_start_close" id="p_grid1Q_10">
#  <th class="l clf" scope="row">
#  <div class=""><span class="txt_acd">기타비용</span><a class="btn_acdopen" href="javascript:foldOpen('grid1Q_10');" id="grid1Q_10"><span class="blind" id="span_grid1Q_10">계산에 참여한 계정 펼치기</span></a></div>
#  </th>
#  <td class="r" title="8,768.96">8,769</td>
#  <td class="r" title="3,227.94">3,228</td>
#  <td class="r" title="5,320.41">5,320</td>
#  <td class="r" title="4,531.10">4,531</td>
#  <td class="r" title="3,242.40">3,242</td>
#  <td class="r cle">39.7</td>
#  </tr>,
#  <tr class="c_grid1Q_10 rwf acd_dep2_sub" style="display:none;">
#  <th class="l clf" scope="row">   이자비용</th>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r cle"> </td>
#  </tr>,
#  <tr class="c_grid1Q_10 rwf acd_dep2_sub" style="display:none;">
#  <th class="l clf" scope="row">   외환손실</th>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r cle"> </td>
#  </tr>,
#  <tr class="c_grid1Q_10 rwf acd_dep2_sub" style="display:none;">
#  <th class="l clf" scope="row">   재고자산감모손실</th>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r cle"> </td>
#  </tr>,
#  <tr class="c_grid1Q_10 rwf acd_dep2_sub" style="display:none;">
#  <th class="l clf" scope="row">   재고자산폐기(처분)손실</th>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r cle"> </td>
#  </tr>,
#  <tr class="c_grid1Q_10 rwf acd_dep2_sub" style="display:none;">
#  <th class="l clf" scope="row">   당기손익-공정가치측정 금융자산평가손실</th>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r cle"> </td>
#  </tr>,
#  <tr class="c_grid1Q_10 rwf acd_dep2_sub" style="display:none;">
#  <th class="l clf" scope="row">   자산처분(폐기)손실</th>
#  <td class="r" title="406.27">406</td>
#  <td class="r" title="191.27">191</td>
#  <td class="r" title="59.90">60</td>
#  <td class="r" title="41.96">42</td>
#  <td class="r" title="98.42">98</td>
#  <td class="r cle"><span class="tcr">-57.4</span></td>
#  </tr>,
#  <tr class="c_grid1Q_10 rwf acd_dep2_sub" style="display:none;">
#  <th class="l clf" scope="row">   자산평가손실</th>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r cle"> </td>
#  </tr>,
#  <tr class="c_grid1Q_10 rwf acd_dep2_sub" style="display:none;">
#  <th class="l clf" scope="row">   자산손상차손</th>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r cle"> </td>
#  </tr>,
#  <tr class="c_grid1Q_10 rwf acd_dep2_sub" style="display:none;">
#  <th class="l clf" scope="row">   파생상품손실</th>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r cle"> </td>
#  </tr>,
#  <tr class="c_grid1Q_10 rwf acd_dep2_sub" style="display:none;">
#  <th class="l clf" scope="row">   기타대손상각비</th>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r cle"> </td>
#  </tr>,
#  <tr class="c_grid1Q_10 rwf acd_dep2_sub" style="display:none;">
#  <th class="l clf" scope="row">   충당부채전입액</th>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r cle"> </td>
#  </tr>,
#  <tr class="c_grid1Q_10 rwf acd_dep2_sub" style="display:none;">
#  <th class="l clf" scope="row">   기타</th>
#  <td class="r" title="8,362.69">8,363</td>
#  <td class="r" title="3,036.67">3,037</td>
#  <td class="r" title="5,260.51">5,261</td>
#  <td class="r" title="4,489.14">4,489</td>
#  <td class="r" title="3,143.98">3,144</td>
#  <td class="r cle">42.8</td>
#  </tr>,
#  <tr class="rwf acd_dep_start_close" id="p_grid1Q_11">
#  <th class="l clf" scope="row">
#  <div class=""><span class="txt_acd">종속기업,공동지배기업및관계기업관련손익</span><a class="btn_acdopen" href="javascript:foldOpen('grid1Q_11');" id="grid1Q_11"><span class="blind" id="span_grid1Q_11">계산에 참여한 계정 펼치기</span></a></div>
#  </th>
#  <td class="r" title="1,874.87">1,875</td>
#  <td class="r" title="2,657.46">2,657</td>
#  <td class="r" title="1,288.62">1,289</td>
#  <td class="r" title="2,324.77">2,325</td>
#  <td class="r" title="1,475.19">1,475</td>
#  <td class="r cle">57.6</td>
#  </tr>,
#  <tr class="c_grid1Q_11 rwf acd_dep2_sub" style="display:none;">
#  <th class="l clf" scope="row">   지분법손익</th>
#  <td class="r" title="1,874.87">1,875</td>
#  <td class="r" title="2,657.46">2,657</td>
#  <td class="r" title="1,288.62">1,289</td>
#  <td class="r" title="2,324.77">2,325</td>
#  <td class="r" title="1,475.19">1,475</td>
#  <td class="r cle">57.6</td>
#  </tr>,
#  <tr class="c_grid1Q_11 rwf acd_dep2_sub" style="display:none;">
#  <th class="l clf" scope="row">   종속기업,공동지배기업및관계기업투자주식처분손익</th>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r cle"> </td>
#  </tr>,
#  <tr class="c_grid1Q_11 rwf acd_dep2_sub" style="display:none;">
#  <th class="l clf" scope="row">   종속기업,공동지배기업및관계기업투자주식손상관련손익</th>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r cle"> </td>
#  </tr>,
#  <tr class="c_grid1Q_11 rwf acd_dep2_sub" style="display:none;">
#  <th class="l clf" scope="row">   기타</th>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r cle"> </td>
#  </tr>,
#  <tr class="rwf rowBold">
#  <th class="l clf" scope="row">
#  <div class="th_b">세전계속사업이익</div>
#  </th>
#  <td class="r" title="128,824.30">128,824</td>
#  <td class="r" title="163,558.69">163,559</td>
#  <td class="r" title="143,628.83">143,629</td>
#  <td class="r" title="150,698.40">150,698</td>
#  <td class="r" title="97,506.45">97,506</td>
#  <td class="r cle">54.6</td>
#  </tr>,
#  <tr class="rwf">
#  <th class="l clf" scope="row">
#  <div class="">법인세비용</div>
#  </th>
#  <td class="r" title="32,479.44">32,479</td>
#  <td class="r" title="40,625.38">40,625</td>
#  <td class="r" title="35,249.35">35,249</td>
#  <td class="r" title="37,452.12">37,452</td>
#  <td class="r" title="26,089.60">26,090</td>
#  <td class="r cle">43.6</td>
#  </tr>,
#  <tr class="rwf">
#  <th class="l clf" scope="row">
#  <div class="">계속영업이익</div>
#  </th>
#  <td class="r" title="96,344.86">96,345</td>
#  <td class="r" title="122,933.31">122,933</td>
#  <td class="r" title="108,379.48">108,379</td>
#  <td class="r" title="113,246.28">113,246</td>
#  <td class="r" title="71,416.85">71,417</td>
#  <td class="r cle">58.6</td>
#  </tr>,
#  <tr class="rwf">
#  <th class="l clf" scope="row">
#  <div class="">중단영업이익</div>
#  </th>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r" title=""> </td>
#  <td class="r cle"> </td>
#  </tr>,
#  <tr class="rwf rowBold">
#  <th class="l clf" scope="row">
#  <div class="th_b">당기순이익</div>
#  </th>
#  <td class="r" title="96,344.86">96,345</td>
#  <td class="r" title="122,933.31">122,933</td>
#  <td class="r" title="108,379.48">108,379</td>
#  <td class="r" title="113,246.28">113,246</td>
#  <td class="r" title="71,416.85">71,417</td>
#  <td class="r cle">58.6</td>
#  </tr>,
#  <tr class="rwf">
#  <th class="l clf" scope="row">
#  <div class="">   지배주주순이익</div>
#  </th>
#  <td class="r" title="94,506.76">94,507</td>
#  <td class="r" title="120,572.07">120,572</td>
#  <td class="r" title="106,431.22">106,431</td>
#  <td class="r" title="111,290.94">111,291</td>
#  <td class="r" title="70,927.86">70,928</td>
#  <td class="r cle">56.9</td>
#  </tr>,
#  <tr class="rwf">
#  <th class="l clf" scope="row">
#  <div class="">   비지배주주순이익</div>
#  </th>
#  <td class="r" title="1,838.10">1,838</td>
#  <td class="r" title="2,361.24">2,361</td>
#  <td class="r" title="1,948.26">1,948</td>
#  <td class="r" title="1,955.34">1,955</td>
#  <td class="r" title="488.99">489</td>
#  <td class="r cle">299.9</td>
#  </tr>]

# %%
items_kr = [is_a[m].find(['th']).get_text().replace('\n', '').replace('\xa0', '').replace('계산에 참여한 계정 펼치기', '')
                for m in range(1, len(is_a))]
items_kr
# Out:
# ['매출액',
#  '매출원가',
#  '매출총이익',
#  '판매비와관리비',
#  '인건비',
#  '유무형자산상각비',
#  '연구개발비',
#  '광고선전비',
#  '판매비',
#  '관리비',
#  '기타원가성비용',
#  '기타',
#  '영업이익',
#  '영업이익(발표기준)',
#  '금융수익',
#  '이자수익',
#  '배당금수익',
#  '외환이익',
#  '대손충당금환입액',
#  '매출채권처분이익',
#  '당기손익-공정가치측정금융자산관련이익',
#  '금융자산처분이익',
#  '금융자산평가이익',
#  '금융자산손상차손환입',
#  '파생상품이익',
#  '기타금융수익',
#  '금융원가',
#  '이자비용',
#  '외환손실',
#  '대손상각비',
#  '당기손익-공정가치측정금융자산관련손실',
#  '매출채권처분손실',
#  '금융자산처분손실',
#  '금융자산평가손실',
#  '금융자산손상차손',
#  '파생상품손실',
#  '기타금융원가',
#  '기타수익',
#  '이자수익',
#  '배당금수익',
#  '외환이익',
#  '재고자산감모손실환입',
#  '재고자산폐기(처분)이익',
#  '당기손익-공정가치측정금융자산평가이익',
#  '자산처분(폐기)이익',
#  '자산평가이익',
#  '자산손상차손환입',
#  '파생상품이익',
#  '임대료수익',
#  '로열티수익',
#  '수수료수익',
#  '대손충당금환입',
#  '충당부채환입액',
#  '기타',
#  '기타비용',
#  '이자비용',
#  '외환손실',
#  '재고자산감모손실',
#  '재고자산폐기(처분)손실',
#  '당기손익-공정가치측정금융자산평가손실',
#  '자산처분(폐기)손실',
#  '자산평가손실',
#  '자산손상차손',
#  '파생상품손실',
#  '기타대손상각비',
#  '충당부채전입액',
#  '기타',
#  '종속기업,공동지배기업및관계기업관련손익',
#  '지분법손익',
#  '종속기업,공동지배기업및관계기업투자주식처분손익',
#  '종속기업,공동지배기업및관계기업투자주식손상관련손익',
#  '기타',
#  '세전계속사업이익',
#  '법인세비용',
#  '계속영업이익',
#  '중단영업이익',
#  '당기순이익',
#  '지배주주순이익',
#  '비지배주주순이익']

# %%
period = [is_a[0].find_all('th')[n].get_text() for n in range(1, num_col + 1)]
period = [period[m].replace('/', '-') for m in range(0, len(period))]
_period = []
for p in period:
    _period.append(datetime.strptime(str(p)[:7], '%Y-%m').date())

globals()['period'] = _period

# %%
for item, i in zip(items_kr, range(1, len(is_a))):
        temps = []
        for j in range(0, num_col):
            temp = [float(is_a[i].find_all('td')[j]['title'].replace(',', '').replace('\xa0', '')) \
                        if is_a[i].find_all('td')[j]['title'].replace(',', '').replace('\xa0', '') != '' \
                        else (0 if is_a[i].find_all('td')[j]['title'].replace(',', '').replace('\xa0', '') == '-0' \
                                  else 0)]
            temps.append(temp[0])

        globals()[item] = temps

# %%
is_domestic = pd.DataFrame({
    '종목코드': stock[0],
    '종목명': stock[2],
    '시장': stock[1],
    '기간': _period,
    '컬럼': rpt_type.lower() + '_' + freq.lower(),
    '매출액': 매출액,
    '매출원가': 매출원가,
    '매출총이익': 매출총이익,
    '판매비': 판매비,
    '관리비': 관리비,
    '영업이익': 영업이익,
    '금융수익': 금융수익,
    '금융원가': 금융원가,
    '기타수익': 기타수익,
    '기타비용': 기타비용,
    '관계기업관련손익': globals()['종속기업,공동지배기업및관계기업관련손익'],
    'EBIT': 세전계속사업이익,
    '법인세비용': 법인세비용,
    '계속영업이익': 계속영업이익,
    '중단영업이익': 중단영업이익,
    '당기순이익': 당기순이익,
    '지배주주순이익': globals()['지배주주순이익'],
    '비지배주주순이익': globals()['비지배주주순이익']
}, index=_period)

# %%
is_domestic
# Out:
#               종목코드   종목명     시장          기간              컬럼        매출액  \
# 2021-06-01  005930  삼성전자  KOSPI  2021-06-01  consolidated_q  636715.85
# 2021-09-01  005930  삼성전자  KOSPI  2021-09-01  consolidated_q  739791.87
# 2021-12-01  005930  삼성전자  KOSPI  2021-12-01  consolidated_q  765655.24
# 2022-03-01  005930  삼성전자  KOSPI  2022-03-01  consolidated_q  777814.98
#
#                  매출원가      매출총이익       판매비       관리비  ...     기타수익     기타비용  \
# 2021-06-01  370659.31  266056.54  26458.35  14686.37  ...  7406.68  8768.96
# 2021-09-01  428988.71  310803.16  35628.16  14454.61  ...  4251.52  3227.94
# 2021-12-01  449465.55  316189.69  38558.94  18174.77  ...  7401.33  5320.41
# 2022-03-01  470720.57  307094.41  35745.75  17303.91  ...  7001.93  4531.10
#
#             관계기업관련손익       EBIT     법인세비용     계속영업이익  중단영업이익      당기순이익  \
# 2021-06-01   1874.87  128824.30  32479.44   96344.86       0   96344.86
# 2021-09-01   2657.46  163558.69  40625.38  122933.31       0  122933.31
# 2021-12-01   1288.62  143628.83  35249.35  108379.48       0  108379.48
# 2022-03-01   2324.77  150698.40  37452.12  113246.28       0  113246.28
#
#               지배주주순이익  비지배주주순이익
# 2021-06-01   94506.76   1838.10
# 2021-09-01  120572.07   2361.24
# 2021-12-01  106431.22   1948.26
# 2022-03-01  111290.94   1955.34
#
# [4 rows x 23 columns]
